# %% [markdown]
# # Aplicativo que realiza conversão dos dados do CSV em SQL
# ## Criado por Thiago da Silva Moraes

# %%
filer = open('brutos\\GastosDiretos.csv')
filew = open('output\\GastosDiretos.txt','w')
fileb = open('brutos\\GastosDiretos.csv')
#filer = open('GastosDiretostT.csv')
#filew = open('output\\teste.txt','w')
#fileb = open('GastosDiretostT.csv')


gastosPublicos()

# %%
filer.close()
filew.close()
fileb.close()

# %%
# Função principal da conversão dos dados do CSV em linguagem SQL
def contador(file):
    abc = 0
    asd = 0
    for row2 in file:
        asd = row2.split('\t')
        for a in asd:
            abc+=1
    return abc

def gastosPublicos():
    counted = contador(fileb)
    dataPgto = 0
    counter = 0
    idOrgaoSuperior = ''
    idOrgaoSubordinado = ''
    idFuncao = ''
    idValorPago = 0
    idPrograma = ''
    idSubFuncao = ''
    idFuncao = ''
    t1 = []
    t2 = []
    t3 = []
    t4 = []
    t5 = []
    
    for row in filer:
        rowArr = row.split('\t')
        i = 1
        for value in rowArr:
            counter += 1
            if i == 1 or i == 2:
                if value not in t1:
                    t1.append(value)
                    if i == 1:
                        idOrgaoSuperior = value
                        filew.write("INSERT INTO orgaosuperior (idOrgaoSuperior, nomeOrgaoSuperior) VALUES (")
                        filew.write(value)
                        filew.write(", '")

                    elif i == 2:
                        filew.write(value)
                        filew.write("');\n")
            elif i == 3 or i == 4:
                if value not in t2:
                    t2.append(value)
                    if i == 3:
                        idOrgaoSubordinado = value
                        filew.write("INSERT INTO orgaosubordinado (idOrgaoSubordinado, nomeOrgaoSubordinado, idOrgaoSuperior) ")
                        filew.write("VALUES (")
                        filew.write(value)
                        filew.write(", '")
                    elif i == 4:
                        filew.write(value)
                        filew.write("', ")
                        filew.write(idOrgaoSuperior)
                        filew.write(");\n")
            elif i == 11 or i == 12:
                if value not in t3:
                    t3.append(value)
                    if i == 11:
                        idFuncao = value
                        filew.write("INSERT INTO funcao (idFuncao, nomeFuncao) VALUES (")
                        filew.write(value)
                        filew.write(", '")
                    elif i == 12:
                        filew.write(value)
                        filew.write("');\n")

                        filew.write("INSERT INTO orgaosubordinado_funcao (idOrgaoSubordinado, idFuncao) VALUES (")
                        filew.write(idOrgaoSubordinado)
                        filew.write(", ")
                        filew.write(idFuncao)
                        filew.write(");\n")
            elif i == 13 or i == 14:
                if value not in t4:
                    t4.append(value)
                    if i == 13:
                        filew.write("INSERT INTO subfuncao (idSubFuncao, nomeSubFuncao) VALUES (")
                        filew.write(value)
                        filew.write(", '")
                        idSubFuncao = value
                    elif i == 14:
                        filew.write(value)
                        filew.write("');\n")
                        
                        filew.write("INSERT INTO subfuncao_funcao (idSubFuncao, idFuncao) VALUES (")
                        filew.write(idSubFuncao)
                        filew.write(", ")
                        filew.write(idFuncao)
                        filew.write(");\n")
            elif i == 15 or 16:
                if value not in t5:
                    t5.append(value)
                    if i == 15:
                        filew.write("INSERT INTO programa (idPrograma, nomePrograma) VALUES (")
                        filew.write(value)
                        filew.write(", '")
                        idPrograma = value
                    elif i == 16:
                        filew.write(value)
                        filew.write("');\n")
                        
                        filew.write("INSERT INTO subfuncao_programa (idSubFuncao, idPrograma) VALUES (")
                        filew.write(idSubFuncao)
                        filew.write(", ")
                        filew.write(idPrograma)
                        filew.write(");\n")
            
            if i == 24 or i == 25:
                if i == 24:
                    dataPgto = substitoi(value)
                if dataPgto != False:
                    if i == 24:
                        filew.write("INSERT INTO valorpago (datapagamento, valor, idValorPago) VALUES ('")
                        filew.write(substitoi(value))
                        filew.write("', ")
                    if i == 25:
                        done = value.strip()
                        idV = str(idValorPago)
                        filew.write(done.replace(',','.'))
                        filew.write(", ")
                        filew.write(idV)
                        filew.write(");\n")

                        filew.write("INSERT INTO programa_valorpago (idPrograma, idValorPago) VALUES(")
                        filew.write(idPrograma)
                        filew.write(", ")
                        filew.write(idV)
                        filew.write(");\n")

                        idValorPago += 1
            i+=1
        print(counter,'/',counted)
    #tempw.write()

# %%
# Função que substitui o valor de data comum DD/MM/AAAA por AAAA-MM-DD aceito pelo MySQL
# Também detecta se o valor inserido não é uma data no formato acima.

def substitoi(valor:str):
    try:
        data = valor.split('/')
        cont = 1
        dia = ''
        mes = ''
        ano = ''
        for i in data:
            if cont == 1:
                dia = str(int(i))
            elif cont == 2:
                mes = i
            elif cont == 3:
                ano = i
            cont+=1
        return ano + '-' + mes + '-'+ dia
    except:
        return False

# %% [markdown]
# ### Daqui pra baixo nada é útil

# %%
def guardarLista(idv, t1, t2, t3, t4, t5):
    tempw = open('temp\\.temp', 'w')

    a = [1, 1651, 1234, 135, '  asda  ']
    for i in a:
        tempw.write(str(i)+"\n")

    tempw.close()    

guardar()

# %%
def lerLista():
    lista = []
    try:
        tempr = open('temp\\.temp', 'r')

        for a in tempr:
            lista.append(a.strip())
        tempr.close()
        return lista
    except:
        print('arquivo não encontrado')
        return '\0'

print(lerLista())
